# %%
import numpy as np
import pandas as pd

# %% [markdown]
# We can use the pd.read_csv function to create a dataframe data type from the csv file.

# %%
df=pd.read_csv("hospital-data.csv")

# %% [markdown]
# df.shape gives us the number of rows and columns in the dataframe.

# %%
df.shape
# Out:
# (4826, 13)

# %% [markdown]
# df.size gives the total number of cells of data in the csv file. Numerically, it is equal to the multiple of the number of rows and colums.

# %%
df.size
# Out:
# 62738

# %% [markdown]
# This gives all column names.

# %%
df.columns
# Out:
# Index(['Provider Number', 'Hospital Name', 'Address 1', 'Address 2',
#        'Address 3', 'City', 'State', 'ZIP Code', 'County', 'Phone Number',
#        'Hospital Type', 'Hospital Ownership', 'Emergency Services'],
#       dtype='object')

# %% [markdown]
# df.City specifies to look for the column named "city", and df.City.value_counts() gives the number of times a certain value appears in the dataframe.

# %%
df.City.value_counts()
# Out:
# CHICAGO         27
# HOUSTON         26
# LOS ANGELES     21
# DALLAS          19
# PHILADELPHIA    17
#                 ..
# BOGALUSA         1
# THIBODAUX        1
# NATCHITOCHES     1
# MORGAN CITY      1
# ADDISON          1
# Name: City, Length: 3018, dtype: int64

# %% [markdown]
# df.dtypes gives the datatype of the data.

# %%
df.dtypes
# Out:
# Provider Number        object
# Hospital Name          object
# Address 1              object
# Address 2             float64
# Address 3             float64
# City                   object
# State                  object
# ZIP Code                int64
# County                 object
# Phone Number            int64
# Hospital Type          object
# Hospital Ownership     object
# Emergency Services     object
# dtype: object

# %%
df.sample(n=10)
# Out:
#      Provider Number                                   Hospital Name  \
# 2900          33015F              VA HUDSON VALLEY HEALTHCARE SYSTEM
# 2324          250044            BAPTIST MEMORIAL HOSPITAL BOONEVILLE
# 3435          370235                            ST JOHN BROKEN ARROW
# 2899          330159  COMMUNITY-GENERAL HOSPITAL OF GREATER SYRACUSE
# 1623          171331                         KIOWA DISTRICT HOSPITAL
# 222           040047                      FIVE RIVERS MEDICAL CENTER
# 3180          360017                            GRANT MEDICAL CENTER
# 2882          330125                      ROCHESTER GENERAL HOSPITAL
# 3871          431326        MILBANK AREA HOSPITAL/AVERA HEALTH - CAH
# 1954          210055                  LAUREL REGIONAL MEDICAL CENTER
#
#                       Address 1  Address 2  Address 3  \
# 2900      2094 ALBANY POST ROAD        NaN        NaN
# 2324         100 HOSPITAL DRIVE        NaN        NaN
# 3435     1000 WEST BOISE CIRCLE        NaN        NaN
# 2899            4900 BROAD ROAD        NaN        NaN
# 1623           810 DRUMM STREET        NaN        NaN
# 222   2801 MEDICAL CENTER DRIVE        NaN        NaN
# 3180     111 SOUTH GRANT AVENUE        NaN        NaN
# 2882       1425 PORTLAND AVENUE        NaN        NaN
# 3871           901 E VIRGIL AVE        NaN        NaN
# 1954        7300 VAN DUSEN ROAD        NaN        NaN
#
#                                 City State  ZIP Code          County  \
# 2900  MONTROSE                          NY     10548     WESTCHESTER
# 2324                      BOONEVILLE    MS     38829        PRENTISS
# 3435                    BROKEN ARROW    OK     74012           TULSA
# 2899                        SYRACUSE    NY     13215        ONONDAGA
# 1623                           KIOWA    KS     67070          BARBER
# 222                       POCAHONTAS    AR     72455        RANDOLPH
# 3180                        COLUMBUS    OH     43215        FRANKLIN
# 2882                       ROCHESTER    NY     14621          MONROE
# 3871                         MILBANK    SD     57252           GRANT
# 1954                          LAUREL    MD     20707  PRINCE GEORGES
#
#       Phone Number                         Hospital Type  \
# 2900    9147374400  ACUTE CARE - VETERANS ADMINISTRATION
# 2324    6627205000                  Acute Care Hospitals
# 3435    9189948199                  Acute Care Hospitals
# 2899    3154925011                  Acute Care Hospitals
# 1623    6208254131             Critical Access Hospitals
# 222     8708926000                  Acute Care Hospitals
# 3180    6145669978                  Acute Care Hospitals
# 2882    5859224000                  Acute Care Hospitals
# 3871    6054324538             Critical Access Hospitals
# 1954    3014977953                  Acute Care Hospitals
#
#                                Hospital Ownership Emergency Services
# 2900                           Government Federal                Yes
# 2324                Voluntary non-profit - Church                Yes
# 3435                                  Proprietary                Yes
# 2899                 Voluntary non-profit-Private      Not Available
# 1623  Government - Hospital District or Authority                Yes
# 222                            Government - Local                Yes
# 3180                Voluntary non-profit - Church                Yes
# 2882               Voluntary non-profit - Private                Yes
# 3871               Voluntary non-profit - Private                Yes
# 1954               Voluntary non-profit - Private                Yes

# %% [markdown]
# df.sample gives random samples in the dataframe and the sample size is specified.

# %%
df.tail()
# Out:
#      Provider Number                           Hospital Name  \
# 4821          670072        WESTBURY COMMUNITY HOSPITAL, LLC
# 4822          670073          METHODIST HOSPITAL FOR SURGERY
# 4823          670075  ST LUKE'S HOSPITAL AT THE VINTAGE, LLC
# 4824          670076         HERITAGE PARK SURGICAL HOSPITAL
# 4825          670077         METHODIST WEST HOUSTON HOSPITAL
#
#                        Address 1  Address 2  Address 3     City State  \
# 4821                 5556 GASMER        NaN        NaN  HOUSTON    TX
# 4822        17101 DALLAS PARKWAY        NaN        NaN  ADDISON    TX
# 4823  20171 CHASEWOOD PARK DRIVE        NaN        NaN  HOUSTON    TX
# 4824           3601 CALAIS DRIVE        NaN        NaN  SHERMAN    TX
# 4825          18500 KATY FREEWAY        NaN        NaN  HOUSTON    TX
#
#       ZIP Code   County  Phone Number         Hospital Type  \
# 4821     77035   HARRIS    7134222650  Acute Care Hospitals
# 4822     75001   DALLAS    4692483900  Acute Care Hospitals
# 4823     77070   HARRIS    8325345000  Acute Care Hospitals
# 4824     75090  GRAYSON    9038133728  Acute Care Hospitals
# 4825     77094   HARRIS    8325221000  Acute Care Hospitals
#
#                   Hospital Ownership Emergency Services
# 4821                     Proprietary                Yes
# 4822                     Proprietary                Yes
# 4823                     Proprietary                Yes
# 4824                     Proprietary                Yes
# 4825  Voluntary non-profit - Private                Yes

# %% [markdown]
# df.tail() gives the last five rows.

# %% [markdown]
# df.State.shape gives the shape of all the data under the state column.

# %%
df.State.shape
# Out:
# (4826,)

# %% [markdown]
# the square brackets are used here to give a new dataframe where only the column named "Emergency Services" is displayed.

# %%
df['Emergency Services']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 4821    Yes
# 4822    Yes
# 4823    Yes
# 4824    Yes
# 4825    Yes
# Name: Emergency Services, Length: 4826, dtype: object

# %%
df['Emergency Services'].value_counts()
# Out:
# Yes              4572
# No                231
# Not Available      23
# Name: Emergency Services, dtype: int64

# %% [markdown]
# Below is an example of generating a new dataframe by using location index, where only the columns "state" and "Hospital Type" are displayed with a random sample size of 5.

# %%
df.loc[:,["State","Hospital Type"]].sample(n=5)
# Out:
#      State              Hospital Type
# 1291    IL  Critical Access Hospitals
# 2492    MO  Critical Access Hospitals
# 794     FL       Acute Care Hospitals
# 3292    OH       Acute Care Hospitals
# 1480    IA  Critical Access Hospitals

# %% [markdown]
# This is an example of using index location to locate the data by indexing the first 3 rows and the first 6 column.

# %%
df.iloc[1:4,1:7]
# Out:
#                     Hospital Name                   Address 1  Address 2  \
# 1   MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH        NaN
# 2  ELIZA COFFEE MEMORIAL HOSPITAL          205 MARENGO STREET        NaN
# 3        MIZELL MEMORIAL HOSPITAL               702 N MAIN ST        NaN
#
#    Address 3      City State
# 1        NaN      BOAZ    AL
# 2        NaN  FLORENCE    AL
# 3        NaN       OPP    AL

# %%
df.loc[0:5,"State"]
# Out:
# 0    AL
# 1    AL
# 2    AL
# 3    AL
# 4    AL
# 5    AL
# Name: State, dtype: object

# %% [markdown]
# Next we can apply data filtering to only leave the data that meets the requirements described in the square brackets. The double equal sign is used here to indicate judgement of equality. This dataframe only gives the data which have North Carolina as the value for the State column.

# %%
df[df["State"]=="NC"]
# Out:
#      Provider Number                                      Hospital Name  \
# 3011          340001                 CAROLINAS MEDICAL CENTER-NORTHEAST
# 3012          340002  MEMORIAL MISSION HOSPITAL AND ASHEVILLE SURGER...
# 3013          340003                  NORTHERN HOSPITAL OF SURRY COUNTY
# 3014          340004                       HIGH POINT REGIONAL HOSPITAL
# 3015          340008                         SCOTLAND MEMORIAL HOSPITAL
# ...              ...                                                ...
# 3119          341323              CHARLES A CANNON JR MEMORIAL HOSPITAL
# 3120          341324                      THE OUTER BANKS HOSPITAL, INC
# 3121          341325                             ASHE MEMORIAL HOSPITAL
# 3122          341326                               ANGEL MEDICAL CENTER
# 3123          341327                  J ARTHUR DOSHER MEMORIAL HOSPITAL
#
#                          Address 1  Address 2  Address 3        City State  \
# 3011               920 CHURCH ST N        NaN        NaN     CONCORD    NC
# 3012              509 BILTMORE AVE        NaN        NaN   ASHEVILLE    NC
# 3013               830 ROCKFORD ST        NaN        NaN  MOUNT AIRY    NC
# 3014     601 N ELM ST  PO BOX HP-5        NaN        NaN  HIGH POINT    NC
# 3015              500 LAUCHWOOD DR        NaN        NaN  LAURINBURG    NC
# ...                            ...        ...        ...         ...   ...
# 3119            434 HOSPITAL DRIVE        NaN        NaN    LINVILLE    NC
# 3120    4800 SOUTH CROATAN HIGHWAY        NaN        NaN   NAGS HEAD    NC
# 3121              200 HOSPITAL AVE        NaN        NaN   JEFFERSON    NC
# 3122  120 RIVERVIEW ST PO BOX 1209        NaN        NaN    FRANKLIN    NC
# 3123                   924 HOWE ST        NaN        NaN   SOUTHPORT    NC
#
#       ZIP Code     County  Phone Number              Hospital Type  \
# 3011     28025   CABARRUS    7047833000       Acute Care Hospitals
# 3012     28801   BUNCOMBE    8282131111       Acute Care Hospitals
# 3013     27030      SURRY    3367197000       Acute Care Hospitals
# 3014     27261   GUILFORD    3368786000       Acute Care Hospitals
# 3015     28352   SCOTLAND    9102917000       Acute Care Hospitals
# ...        ...        ...           ...                        ...
# 3119     28646      AVERY    8287377000  Critical Access Hospitals
# 3120     27959       DARE    2524494500  Critical Access Hospitals
# 3121     28640       ASHE    3362467101  Critical Access Hospitals
# 3122     28734      MACON    8285248411  Critical Access Hospitals
# 3123     28461  BRUNSWICK    9104573800  Critical Access Hospitals
#
#                                Hospital Ownership Emergency Services
# 3011  Government - Hospital District or Authority                Yes
# 3012               Voluntary non-profit - Private                Yes
# 3013  Government - Hospital District or Authority                Yes
# 3014               Voluntary non-profit - Private                Yes
# 3015               Voluntary non-profit - Private                Yes
# ...                                           ...                ...
# 3119               Voluntary non-profit - Private                Yes
# 3120               Voluntary non-profit - Private                Yes
# 3121               Voluntary non-profit - Private                Yes
# 3122               Voluntary non-profit - Private                Yes
# 3123                 Voluntary non-profit - Other                Yes
#
# [113 rows x 13 columns]

# %% [markdown]
# Of course, we can create another independent dataframe to differentiate it from the original dataframe df.

# %%
NC=df[df["State"]=="NC"].copy()

# %%
NC
# Out:
#      Provider Number                                      Hospital Name  \
# 3011          340001                 CAROLINAS MEDICAL CENTER-NORTHEAST
# 3012          340002  MEMORIAL MISSION HOSPITAL AND ASHEVILLE SURGER...
# 3013          340003                  NORTHERN HOSPITAL OF SURRY COUNTY
# 3014          340004                       HIGH POINT REGIONAL HOSPITAL
# 3015          340008                         SCOTLAND MEMORIAL HOSPITAL
# ...              ...                                                ...
# 3119          341323              CHARLES A CANNON JR MEMORIAL HOSPITAL
# 3120          341324                      THE OUTER BANKS HOSPITAL, INC
# 3121          341325                             ASHE MEMORIAL HOSPITAL
# 3122          341326                               ANGEL MEDICAL CENTER
# 3123          341327                  J ARTHUR DOSHER MEMORIAL HOSPITAL
#
#                          Address 1  Address 2  Address 3        City State  \
# 3011               920 CHURCH ST N        NaN        NaN     CONCORD    NC
# 3012              509 BILTMORE AVE        NaN        NaN   ASHEVILLE    NC
# 3013               830 ROCKFORD ST        NaN        NaN  MOUNT AIRY    NC
# 3014     601 N ELM ST  PO BOX HP-5        NaN        NaN  HIGH POINT    NC
# 3015              500 LAUCHWOOD DR        NaN        NaN  LAURINBURG    NC
# ...                            ...        ...        ...         ...   ...
# 3119            434 HOSPITAL DRIVE        NaN        NaN    LINVILLE    NC
# 3120    4800 SOUTH CROATAN HIGHWAY        NaN        NaN   NAGS HEAD    NC
# 3121              200 HOSPITAL AVE        NaN        NaN   JEFFERSON    NC
# 3122  120 RIVERVIEW ST PO BOX 1209        NaN        NaN    FRANKLIN    NC
# 3123                   924 HOWE ST        NaN        NaN   SOUTHPORT    NC
#
#       ZIP Code     County  Phone Number              Hospital Type  \
# 3011     28025   CABARRUS    7047833000       Acute Care Hospitals
# 3012     28801   BUNCOMBE    8282131111       Acute Care Hospitals
# 3013     27030      SURRY    3367197000       Acute Care Hospitals
# 3014     27261   GUILFORD    3368786000       Acute Care Hospitals
# 3015     28352   SCOTLAND    9102917000       Acute Care Hospitals
# ...        ...        ...           ...                        ...
# 3119     28646      AVERY    8287377000  Critical Access Hospitals
# 3120     27959       DARE    2524494500  Critical Access Hospitals
# 3121     28640       ASHE    3362467101  Critical Access Hospitals
# 3122     28734      MACON    8285248411  Critical Access Hospitals
# 3123     28461  BRUNSWICK    9104573800  Critical Access Hospitals
#
#                                Hospital Ownership Emergency Services
# 3011  Government - Hospital District or Authority                Yes
# 3012               Voluntary non-profit - Private                Yes
# 3013  Government - Hospital District or Authority                Yes
# 3014               Voluntary non-profit - Private                Yes
# 3015               Voluntary non-profit - Private                Yes
# ...                                           ...                ...
# 3119               Voluntary non-profit - Private                Yes
# 3120               Voluntary non-profit - Private                Yes
# 3121               Voluntary non-profit - Private                Yes
# 3122               Voluntary non-profit - Private                Yes
# 3123                 Voluntary non-profit - Other                Yes
#
# [113 rows x 13 columns]

# %% [markdown]
# Now let's generate the same data for the state of South Carolina and glue the two dataframes together.

# %%
SC=df[df["State"]=="SC"].copy()

# %%
SC
# Out:
#      Provider Number                        Hospital Name  \
# 3770          420002              PIEDMONT MEDICAL CENTER
# 3771          420004                  MUSC MEDICAL CENTER
# 3772          420005       MCLEOD MEDICAL CENTER - DILLON
# 3773          420007  SPARTANBURG REGIONAL MEDICAL CENTER
# 3774          420009                OCONEE MEDICAL CENTER
# ...              ...                                  ...
# 3828          421300            ALLENDALE COUNTY HOSPITAL
# 3829          421301        ABBEVILLE AREA MEDICAL CENTER
# 3830          421302          FAIRFIELD MEMORIAL HOSPITAL
# 3831          421303       WILLIAMSBURG REGIONAL HOSPITAL
# 3832          421304            EDGEFIELD COUNTY HOSPITAL
#
#                                  Address 1  Address 2  Address 3         City  \
# 3770                     222 S HERLONG AVE        NaN        NaN    ROCK HILL
# 3771                        169 ASHLEY AVE        NaN        NaN   CHARLESTON
# 3772                      301 E JACKSON ST        NaN        NaN       DILLON
# 3773                         101 E WOOD ST        NaN        NaN  SPARTANBURG
# 3774                    298 MEMORIAL DRIVE        NaN        NaN       SENECA
# ...                                    ...        ...        ...          ...
# 3828  1787 ALLENDALE FAIRFAX RD PO BOX 218        NaN        NaN      FAIRFAX
# 3829                    420 THOMSON CIRCLE        NaN        NaN    ABBEVILLE
# 3830                 321 BYPASS PO BOX 620        NaN        NaN    WINNSBORO
# 3831                  500 NELSON BOULEVARD        NaN        NaN    KINGSTREE
# 3832    300 RIDGE MEDICAL PLAZA PO BOX 590        NaN        NaN    EDGEFIELD
#
#      State  ZIP Code        County  Phone Number              Hospital Type  \
# 3770    SC     29730          YORK    8033291234       Acute Care Hospitals
# 3771    SC     29425    CHARLESTON    8437922300       Acute Care Hospitals
# 3772    SC     29536        DILLON    8437744111       Acute Care Hospitals
# 3773    SC     29303   SPARTANBURG    8645606000       Acute Care Hospitals
# 3774    SC     29672        OCONEE    8648823351       Acute Care Hospitals
# ...    ...       ...           ...           ...                        ...
# 3828    SC     29827     ALLENDALE    8036323311  Critical Access Hospitals
# 3829    SC     29620     ABBEVILLE    8643665011  Critical Access Hospitals
# 3830    SC     29180     FAIRFIELD    8036350233  Critical Access Hospitals
# 3831    SC     29556  WILLIAMSBURG    8433558888  Critical Access Hospitals
# 3832    SC     29824     EDGEFIELD    8036373174  Critical Access Hospitals
#
#                                Hospital Ownership Emergency Services
# 3770                                  Proprietary                Yes
# 3771                           Government - State                Yes
# 3772               Voluntary non-profit - Private                Yes
# 3773  Government - Hospital District or Authority                Yes
# 3774               Voluntary non-profit - Private                Yes
# ...                                           ...                ...
# 3828                           Government - Local                Yes
# 3829               Voluntary non-profit - Private                Yes
# 3830                           Government - Local                Yes
# 3831               Voluntary non-profit - Private                Yes
# 3832                           Government - Local                Yes
#
# [63 rows x 13 columns]

# %%
Carolina=pd.concat([NC,SC],axis=0,ignore_index=True,sort=False)

# %%
Carolina
# Out:
#     Provider Number                                      Hospital Name  \
# 0            340001                 CAROLINAS MEDICAL CENTER-NORTHEAST
# 1            340002  MEMORIAL MISSION HOSPITAL AND ASHEVILLE SURGER...
# 2            340003                  NORTHERN HOSPITAL OF SURRY COUNTY
# 3            340004                       HIGH POINT REGIONAL HOSPITAL
# 4            340008                         SCOTLAND MEMORIAL HOSPITAL
# ..              ...                                                ...
# 171          421300                          ALLENDALE COUNTY HOSPITAL
# 172          421301                      ABBEVILLE AREA MEDICAL CENTER
# 173          421302                        FAIRFIELD MEMORIAL HOSPITAL
# 174          421303                     WILLIAMSBURG REGIONAL HOSPITAL
# 175          421304                          EDGEFIELD COUNTY HOSPITAL
#
#                                 Address 1  Address 2  Address 3        City  \
# 0                         920 CHURCH ST N        NaN        NaN     CONCORD
# 1                        509 BILTMORE AVE        NaN        NaN   ASHEVILLE
# 2                         830 ROCKFORD ST        NaN        NaN  MOUNT AIRY
# 3               601 N ELM ST  PO BOX HP-5        NaN        NaN  HIGH POINT
# 4                        500 LAUCHWOOD DR        NaN        NaN  LAURINBURG
# ..                                    ...        ...        ...         ...
# 171  1787 ALLENDALE FAIRFAX RD PO BOX 218        NaN        NaN     FAIRFAX
# 172                    420 THOMSON CIRCLE        NaN        NaN   ABBEVILLE
# 173                 321 BYPASS PO BOX 620        NaN        NaN   WINNSBORO
# 174                  500 NELSON BOULEVARD        NaN        NaN   KINGSTREE
# 175    300 RIDGE MEDICAL PLAZA PO BOX 590        NaN        NaN   EDGEFIELD
#
#     State  ZIP Code        County  Phone Number              Hospital Type  \
# 0      NC     28025      CABARRUS    7047833000       Acute Care Hospitals
# 1      NC     28801      BUNCOMBE    8282131111       Acute Care Hospitals
# 2      NC     27030         SURRY    3367197000       Acute Care Hospitals
# 3      NC     27261      GUILFORD    3368786000       Acute Care Hospitals
# 4      NC     28352      SCOTLAND    9102917000       Acute Care Hospitals
# ..    ...       ...           ...           ...                        ...
# 171    SC     29827     ALLENDALE    8036323311  Critical Access Hospitals
# 172    SC     29620     ABBEVILLE    8643665011  Critical Access Hospitals
# 173    SC     29180     FAIRFIELD    8036350233  Critical Access Hospitals
# 174    SC     29556  WILLIAMSBURG    8433558888  Critical Access Hospitals
# 175    SC     29824     EDGEFIELD    8036373174  Critical Access Hospitals
#
#                               Hospital Ownership Emergency Services
# 0    Government - Hospital District or Authority                Yes
# 1                 Voluntary non-profit - Private                Yes
# 2    Government - Hospital District or Authority                Yes
# 3                 Voluntary non-profit - Private                Yes
# 4                 Voluntary non-profit - Private                Yes
# ..                                           ...                ...
# 171                           Government - Local                Yes
# 172               Voluntary non-profit - Private                Yes
# 173                           Government - Local                Yes
# 174               Voluntary non-profit - Private                Yes
# 175                           Government - Local                Yes
#
# [176 rows x 13 columns]

# %% [markdown]
# Now we have a dataframe only consisting of the hospital date in NC and SC.

# %% [markdown]
# Now let's try merging data.

# %%
series1=df.loc[:,["State","Hospital Type"]].sample(n=10)

# %%
series2=df.loc[:,["Hospital Name","Hospital Type"]].sample(n=10)

# %%
Merge_data=pd.merge(series1,series2)

# %%
Merge_data
# Out:
#    State              Hospital Type                              Hospital Name
# 0     GA       Acute Care Hospitals                      SAINT JOSEPH HOSPITAL
# 1     GA       Acute Care Hospitals  FLORIDA HOSPITAL HEARTLAND MEDICAL CENTER
# 2     GA       Acute Care Hospitals             CONROE REGIONAL MEDICAL CENTER
# 3     GA       Acute Care Hospitals          RIVERSIDE SHORE MEMORIAL HOSPITAL
# 4     GA       Acute Care Hospitals                  CENTENNIAL MEDICAL CENTER
# 5     GA       Acute Care Hospitals           MCDUFFIE REGIONAL MEDICAL CENTER
# 6     GA       Acute Care Hospitals               VOLUNTEER COMMUNITY HOSPITAL
# 7     PA       Acute Care Hospitals                      SAINT JOSEPH HOSPITAL
# 8     PA       Acute Care Hospitals  FLORIDA HOSPITAL HEARTLAND MEDICAL CENTER
# 9     PA       Acute Care Hospitals             CONROE REGIONAL MEDICAL CENTER
# 10    PA       Acute Care Hospitals          RIVERSIDE SHORE MEMORIAL HOSPITAL
# 11    PA       Acute Care Hospitals                  CENTENNIAL MEDICAL CENTER
# 12    PA       Acute Care Hospitals           MCDUFFIE REGIONAL MEDICAL CENTER
# 13    PA       Acute Care Hospitals               VOLUNTEER COMMUNITY HOSPITAL
# 14    IL       Acute Care Hospitals                      SAINT JOSEPH HOSPITAL
# 15    IL       Acute Care Hospitals  FLORIDA HOSPITAL HEARTLAND MEDICAL CENTER
# 16    IL       Acute Care Hospitals             CONROE REGIONAL MEDICAL CENTER
# 17    IL       Acute Care Hospitals          RIVERSIDE SHORE MEMORIAL HOSPITAL
# 18    IL       Acute Care Hospitals                  CENTENNIAL MEDICAL CENTER
# 19    IL       Acute Care Hospitals           MCDUFFIE REGIONAL MEDICAL CENTER
# 20    IL       Acute Care Hospitals               VOLUNTEER COMMUNITY HOSPITAL
# 21    UT       Acute Care Hospitals                      SAINT JOSEPH HOSPITAL
# 22    UT       Acute Care Hospitals  FLORIDA HOSPITAL HEARTLAND MEDICAL CENTER
# 23    UT       Acute Care Hospitals             CONROE REGIONAL MEDICAL CENTER
# 24    UT       Acute Care Hospitals          RIVERSIDE SHORE MEMORIAL HOSPITAL
# 25    UT       Acute Care Hospitals                  CENTENNIAL MEDICAL CENTER
# 26    UT       Acute Care Hospitals           MCDUFFIE REGIONAL MEDICAL CENTER
# 27    UT       Acute Care Hospitals               VOLUNTEER COMMUNITY HOSPITAL
# 28    KY       Acute Care Hospitals                      SAINT JOSEPH HOSPITAL
# 29    KY       Acute Care Hospitals  FLORIDA HOSPITAL HEARTLAND MEDICAL CENTER
# 30    KY       Acute Care Hospitals             CONROE REGIONAL MEDICAL CENTER
# 31    KY       Acute Care Hospitals          RIVERSIDE SHORE MEMORIAL HOSPITAL
# 32    KY       Acute Care Hospitals                  CENTENNIAL MEDICAL CENTER
# 33    KY       Acute Care Hospitals           MCDUFFIE REGIONAL MEDICAL CENTER
# 34    KY       Acute Care Hospitals               VOLUNTEER COMMUNITY HOSPITAL
# 35    NC       Acute Care Hospitals                      SAINT JOSEPH HOSPITAL
# 36    NC       Acute Care Hospitals  FLORIDA HOSPITAL HEARTLAND MEDICAL CENTER
# 37    NC       Acute Care Hospitals             CONROE REGIONAL MEDICAL CENTER
# 38    NC       Acute Care Hospitals          RIVERSIDE SHORE MEMORIAL HOSPITAL
# 39    NC       Acute Care Hospitals                  CENTENNIAL MEDICAL CENTER
# 40    NC       Acute Care Hospitals           MCDUFFIE REGIONAL MEDICAL CENTER
# 41    NC       Acute Care Hospitals               VOLUNTEER COMMUNITY HOSPITAL
# 42    CA       Acute Care Hospitals                      SAINT JOSEPH HOSPITAL
# 43    CA       Acute Care Hospitals  FLORIDA HOSPITAL HEARTLAND MEDICAL CENTER
# 44    CA       Acute Care Hospitals             CONROE REGIONAL MEDICAL CENTER
# 45    CA       Acute Care Hospitals          RIVERSIDE SHORE MEMORIAL HOSPITAL
# 46    CA       Acute Care Hospitals                  CENTENNIAL MEDICAL CENTER
# 47    CA       Acute Care Hospitals           MCDUFFIE REGIONAL MEDICAL CENTER
# 48    CA       Acute Care Hospitals               VOLUNTEER COMMUNITY HOSPITAL
# 49    IN  Critical Access Hospitals                         COLUMBUS COM HSPTL
# 50    IN  Critical Access Hospitals         MCKENZIE COUNTY HEALTHCARE SYSTEMS
# 51    MS  Critical Access Hospitals                         COLUMBUS COM HSPTL
# 52    MS  Critical Access Hospitals         MCKENZIE COUNTY HEALTHCARE SYSTEMS
# 53    VT  Critical Access Hospitals                         COLUMBUS COM HSPTL
# 54    VT  Critical Access Hospitals         MCKENZIE COUNTY HEALTHCARE SYSTEMS

# %%
Merge_data.to_csv("Merge_data.csv", index=False)

# %%
Carolina.to_csv("Carolina.csv",index=False)
